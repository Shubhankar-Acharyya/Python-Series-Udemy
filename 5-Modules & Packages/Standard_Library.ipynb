# %%
import array
arr=array.array('i',[1,2,3,4,5])

print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 4
# cherry

# %%
### File and directory Access

import os
print(os.getcwd())
# Out:
# c:\Users\shubh\OneDrive\Desktop\Python Series Udemy\5-Modules & Packages

# %%
## High Level Operations on files and collection of files

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization

import json
data={'name':'Shubhankar','age':22}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Shubhankar", "age": 22}
# <class 'str'>
# {'name': 'Shubhankar', 'age': 22}
# <class 'dict'>

# %%
## csv

import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Shubhankar',22])

with open('example.csv',mode='r') as file:

    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Shubhankar', '22']

# %%
## datetime

from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-08-15 09:52:32.585732
# 2026-08-14 09:52:32.585732

# %%
## time

import time

print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1786767818.280349
# 1786767820.2814908

# %%
## Regular Expression

import re

pattern = r'\d+'

text='There are 123 apple'

match=re.search(pattern,text)
print(match.group())
# Out:
# 123
