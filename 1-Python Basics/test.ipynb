# %%
1+1
# Out:
# 2

# %%
print("Hello World")
# Out:
# Hello World

# %%
##  Multi-line comment does not work in .ipynb files. Use single line comments instead.
'''Hi'''
##Hi
# Out:
# 'Hi'

# %% [markdown]
# Indentation

# %%
age = 22
if age>18:
    
    print("You are an adult.")

print(age)
# Out:
# You are an adult.
# 22

# %% [markdown]
# Line Continuation

# %%
total = 1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %% [markdown]
# Multiple Statements on a Single Line

# %%
x = 5; y = 10; z = x+y

print(z)
# Out:
# 15

# %% [markdown]
# Type Inference or Dynamic Typing

# %%
var = 10
print(type(var))

var = "Shubh"
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>
